# %% [markdown]
# # Smile Classification
#
# The object is to recognize smile / non-smile image.

# %%
from __future__ import print_function
# import os
# os.environ['TF_CPP_MIN_LOG_LEVEL']='2'
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import os
import sys
import tarfile
from scipy import ndimage
from six.moves.urllib.request import urlretrieve
from six.moves import cPickle as pickle
import random
import hashlib

# %% [markdown]
# Load the data in more manageable format, load each class into a separate dataset, store them on disk. Later we will merge into a single dataset.
#
# We will convert the entire dataset into a 3D array(image index, x, y) of floating point values, normalize to have approximately **zero mean** and standard **deviation ~0.5** to make training easier.

# %%
num_classes = 2
train_folders = ['datasets/train_folder/0', 'datasets/train_folder/1']
test_folders = ['datasets/test_folder/0', 'datasets/test_folder/1']

image_size = 64
pixel_depth = 255.0
image_depth = 3

def load_image(folder, min_num_images):
  """Load the image for a single smile/non-smile lable."""
  image_files = os.listdir(folder)
  dataset = np.ndarray(shape=(len(image_files), image_size, image_size, image_depth),
                         dtype=np.float32)
  image_index = 0
  for image in os.listdir(folder):
    image_file = os.path.join(folder, image)
    try:
      image_data = (ndimage.imread(image_file).astype(float) - 
                    pixel_depth / 2) / pixel_depth
      # print(image_data)
      if image_data.shape != (image_size, image_size, image_depth):
        raise Exception('Unexpected image shape: %s' % str(image_data.shape))
      dataset[image_index, :, :, :] = image_data
      image_index += 1
    except IOError as e:
      print('Could not read:', image_file, ':', e, '- it\'s ok, skipping.')
    
  num_images = image_index
  dataset = dataset[0:num_images, :, :]
  if num_images < min_num_images:
    raise Exception('Many fewer images than expected: %d < %d' %
                    (num_images, min_num_images))
    
  print('Full dataset tensor:', dataset.shape)
  print('Mean:', np.mean(dataset))
  print('Standard deviation:', np.std(dataset))
  return dataset
# Pickling datasets/train_folder/0.pickle.
# Full dataset tensor: (1238, 64, 64, 3)
# Mean: -0.0335986
# Standard deviation: 0.247544
# Pickling datasets/train_folder/1.pickle.
# Full dataset tensor: (1562, 64, 64, 3)
# Mean: -0.0137995
# Standard deviation: 0.249232
# Pickling datasets/test_folder/0.pickle.
# Full dataset tensor: (600, 64, 64, 3)
# Mean: -0.0210533
# Standard deviation: 0.249451
# Pickling datasets/test_folder/1.pickle.
# Full dataset tensor: (600, 64, 64, 3)
# Mean: -0.00345457
# Standard deviation: 0.249467

def maybe_pickle(data_folders, min_num_images_per_class, force=False):
  dataset_names = []
  for folder in data_folders:
    set_filename = folder + '.pickle'
    dataset_names.append(set_filename)
    if os.path.exists(set_filename) and not force:
      # You may override by setting force=True.
      print('%s already present - Skipping pickling.' % set_filename)
    else:
      print('Pickling %s.' % set_filename)
      dataset = load_image(folder, min_num_images_per_class)
      try:
        with open(set_filename, 'wb') as f:
          pickle.dump(dataset, f, pickle.HIGHEST_PROTOCOL)
      except Exception as e:
        print('Unable to save data to', set_filename, ':', e)
  
  return dataset_names

train_datasets = maybe_pickle(train_folders, 1200)
test_datasets = maybe_pickle(test_folders, 500)
# Out:
# datasets/train_folder/0.pickle already present - Skipping pickling.
# datasets/train_folder/1.pickle already present - Skipping pickling.
# datasets/test_folder/0.pickle already present - Skipping pickling.
# datasets/test_folder/1.pickle already present - Skipping pickling.

# %% [markdown]
# A bit problem is that the classes are not well balanced. Smile size: 2162, non-smile size: 1838
#
# So we will prune smile dataset to make both classes balanced.
# Also create a validation dataset for later tuning. Eg: early termination...

# %%
def make_arrays(nb_rows, img_size, img_depth=3):
  if nb_rows:
    dataset = np.ndarray((nb_rows, img_size, img_size, img_depth), dtype=np.float32)
    labels = np.ndarray(nb_rows, dtype=np.int32)
  else:
    dataset, labels = None, None
  return dataset, labels

def merge_datasets(pickle_files, train_size, valid_size=0):
  num_classes = len(pickle_files)

  valid_dataset, valid_labels = make_arrays(valid_size, image_size)
  train_dataset, train_labels = make_arrays(train_size, image_size)
  vsize_per_class = valid_size // num_classes
  tsize_per_class = train_size // num_classes
    
  start_v, start_t = 0, 0
  end_v, end_t = vsize_per_class, tsize_per_class
  end_l = vsize_per_class+tsize_per_class
  for label, pickle_file in enumerate(pickle_files):
    # print(pickle_file)
    
    try:
      with open(pickle_file, 'rb') as f:
        smile_nonsmile_set = pickle.load(f)
    
        # let's shuffle the smile / nonsmile class
        # to have random validation and training set
        np.random.shuffle(smile_nonsmile_set)
        if valid_dataset is not None:
          valid_smile_nonsmile = smile_nonsmile_set[:vsize_per_class, :, :]
          valid_dataset[start_v:end_v, :, :] = valid_smile_nonsmile
          valid_labels[start_v:end_v] = label
          start_v += vsize_per_class
          end_v += vsize_per_class
                    
        train_smile_nonsmile = smile_nonsmile_set[vsize_per_class:end_l, :, :]
        train_dataset[start_t:end_t, :, :] = train_smile_nonsmile
        train_labels[start_t:end_t] = label

        start_t += tsize_per_class
        end_t += tsize_per_class
    except Exception as e:
      print('Unable to process data from', pickle_file, ':', e)
      raise
  return valid_dataset, valid_labels, train_dataset, train_labels

# train_size = 2800
train_size = 2400
valid_size = 600
test_size = 600

_, _, train_dataset, train_labels = merge_datasets(
  train_datasets, train_size)
valid_dataset, valid_labels, test_dataset, test_labels = merge_datasets(
  test_datasets, test_size, valid_size)

print('Training:', train_dataset.shape, train_labels.shape)
print('Validation:', valid_dataset.shape, valid_labels.shape)
print('Testing:', test_dataset.shape, test_labels.shape)
# Out:
# Training: (2400, 64, 64, 3) (2400,)
# Validation: (600, 64, 64, 3) (600,)
# Testing: (600, 64, 64, 3) (600,)

# %% [markdown]
# Next, we'll randomize the data. It's important to have the labels well shuffled for the training and test distributions to match.

# %%
def randomize(dataset, labels):
  permutation = np.random.permutation(labels.shape[0])
  shuffled_dataset = dataset[permutation,:,:]
  shuffled_labels = labels[permutation]
  return shuffled_dataset, shuffled_labels
train_dataset, train_labels = randomize(train_dataset, train_labels)
test_dataset, test_labels = randomize(test_dataset, test_labels)
valid_dataset, valid_labels = randomize(valid_dataset, valid_labels)

# pretty_labels = {0: 'non-smile', 1: 'smile'}
# def disp_sample_dataset(dataset, labels):
#   print(labels)
#   print(labels.shape)
#   print(dataset)
#   print(dataset.shape)
#   items = random.sample(range(len(labels)), 8)
#   for i, item in enumerate(items):
#     print(item)
#     plt.subplot(2, 4, i+1)
#     plt.axis('off')
#     plt.title(pretty_labels[labels[item]])
#     plt.imshow(dataset[item],interpolation='nearest')
#     plt.show()
# disp_sample_dataset(train_dataset, train_labels)

# %% [markdown]
# Save the data for later reuse.

# %%
pickle_file = 'GENKI4K.pickle'

try:
  f = open(pickle_file, 'wb')
  save = {
    'train_dataset': train_dataset,
    'train_labels': train_labels,
    'valid_dataset': valid_dataset,
    'valid_labels': valid_labels,
    'test_dataset': test_dataset,
    'test_labels': test_labels,
    }
  pickle.dump(save, f, pickle.HIGHEST_PROTOCOL)
  f.close()
except Exception as e:
  print('Unable to save data to', pickle_file, ':', e)
  raise

statinfo = os.stat(pickle_file)
print('Compressed pickle size:', statinfo.st_size)
# Out:
# Compressed pickle size: 176962046

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# * convolutions need the image data formatted as a cube (width by height by #channels)
# * labels as float 1-hot encodings.

# %%
num_labels = 2
num_channels = image_depth # = 3 (RGB)
def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (2400, 64, 64, 3) (2400, 2)
# Validation set (600, 64, 64, 3) (600, 2)
# Test set (600, 64, 64, 3) (600, 2)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# First let's build a small network with two convolution layers, followed by one fully connected layer:
# * conv2d+ReLU - 64x64x16
# * maxpooling  - 32x32x16
# * conv2d+ReLU - 32x32x16
# * maxpooling  - 16x16x16
# * FC + ReLU   - 4096x64
# * FC +softmax - 64x2

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  # depth: so filter
  # 64x64x16

  layer1_biases = tf.Variable(tf.zeros([depth]))

  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  # 32x32x16

  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  # 16x16x16x64
  # 4096x64

  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  # 64x2
  
  # Model.
  def model(data):
    conv1 = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    bias1 = tf.nn.relu(conv1 + layer1_biases)
    pool1 = tf.nn.max_pool(bias1, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    conv2 = tf.nn.conv2d(pool1, layer2_weights, [1, 1, 1, 1], padding='SAME')
    bias2 = tf.nn.relu(conv2 + layer2_biases)
    pool2 = tf.nn.max_pool(bias2, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    shape = pool2.get_shape().as_list()
    reshape = tf.reshape(pool2, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))

  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 0.771831
# Minibatch accuracy: 62.5%
# Validation accuracy: 50.0%
# Minibatch loss at step 50: 0.706261
# Minibatch accuracy: 43.8%
# Validation accuracy: 55.8%
# Minibatch loss at step 100: 0.600213
# Minibatch accuracy: 62.5%
# Validation accuracy: 56.8%
# Minibatch loss at step 150: 0.759039
# Minibatch accuracy: 43.8%
# Validation accuracy: 58.5%
# Minibatch loss at step 200: 0.685244
# Minibatch accuracy: 62.5%
# Validation accuracy: 59.8%
# Minibatch loss at step 250: 0.636330
# Minibatch accuracy: 62.5%
# Validation accuracy: 67.8%
# Minibatch loss at step 300: 0.512270
# Minibatch accuracy: 87.5%
# Validation accuracy: 66.7%
# Minibatch loss at step 350: 0.528772
# Minibatch accuracy: 81.2%
# Validation accuracy: 72.3%
# Minibatch loss at step 400: 0.658931
# Minibatch accuracy: 68.8%
# Validation accuracy: 70.8%
# Minibatch loss at step 450: 0.400845
# Minibatch accuracy: 87.5%
# Validation accuracy: 71.2%
# Minibatch loss at step 500: 0.399185
# Minibatch accuracy: 81.2%
# Validation accuracy: 71.2%
# Minibatch loss at step 550: 0.431613
# Minibatch accuracy: 75.0%
# Validation accuracy: 59.7%
# Minibatch loss at step 600: 0.310785
# Minibatch accuracy: 93.8%
# Validation accuracy: 71.5%
# Minibatch loss at step 650: 0.439651
# Minibatch accuracy: 75.0%
# Validation accuracy: 65.5%
# Minibatch loss at step 700: 0.586649
# Minibatch accuracy: 62.5%
# Validation accuracy: 79.7%
# Minibatch loss at step 750: 0.310055
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.3%
# Minibatch loss at step 800: 0.378937
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.5%
# Minibatch loss at step 850: 0.451829
# Minibatch accuracy: 68.8%
# Validation accuracy: 76.0%
# Minibatch loss at step 900: 0.271207
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.5%
# Minibatch loss at step 950: 0.633245
# Minibatch accuracy: 75.0%
# Validation accuracy: 75.0%
# Minibatch loss at step 1000: 0.276625
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.0%
# Test accuracy: 82.0%

# %% [markdown]
# Next we will implement dropout and learning rate decay:

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64
beta_regul = 1e-3
drop_out = 0.5

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  global_step = tf.Variable(0)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  # depth: so filter
  # 64x64x16

  layer1_biases = tf.Variable(tf.zeros([depth]))

  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  # 32x32x16

  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  # 16x16x16x64
  # 4096x64

  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  # 64x2
  
  # Model.
  def model(data, keep_prob):
    conv1 = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    bias1 = tf.nn.relu(conv1 + layer1_biases)
    pool1 = tf.nn.max_pool(bias1, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    conv2 = tf.nn.conv2d(pool1, layer2_weights, [1, 1, 1, 1], padding='SAME')
    bias2 = tf.nn.relu(conv2 + layer2_biases)
    pool2 = tf.nn.max_pool(bias2, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    shape = pool2.get_shape().as_list()
    reshape = tf.reshape(pool2, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    drop = tf.nn.dropout(hidden, keep_prob)
    return tf.matmul(drop, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset, drop_out)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=tf_train_labels))
    
  # Optimizer.
  learning_rate = tf.train.exponential_decay(0.05, global_step, 1000, 0.85, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset, 1.0))
  test_prediction = tf.nn.softmax(model(tf_test_dataset, 1.0))

num_steps = 5001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))

  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))

# %% [markdown]
# Next we will try to implement LeNet5 architecture, but slightly diffrent, consist of two sets of convolutional, followed by 2 fully-connected layers:
# * Input - 64x64x3
# * conv1 + ReLU - 60x60x16
# * avg_pool - 30x30x16
# * conv3 + ReLU - 26x26x16
# * avg_pool - 13x13x16
# * FC + ReLU
# * FC 64x2 + softmax

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  size3 = ((image_size - patch_size + 1) // 2 - patch_size + 1) // 2
  layer3_weights = tf.Variable(tf.truncated_normal(
      [size3 * size3 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    # C1 input 28 x 28
    conv1 = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='VALID')
    bias1 = tf.nn.relu(conv1 + layer1_biases)
    # S2 input 24 x 24
    pool2 = tf.nn.avg_pool(bias1, [1, 2, 2, 1], [1, 2, 2, 1], padding='VALID')
    # C3 input 12 x 12
    conv3 = tf.nn.conv2d(pool2, layer2_weights, [1, 1, 1, 1], padding='VALID')
    bias3 = tf.nn.relu(conv3 + layer2_biases)
    # S4 input 8 x 8
    pool4 = tf.nn.avg_pool(bias3, [1, 2, 2, 1], [1, 2, 2, 1], padding='VALID')
    # F6 input 4 x 4
    shape = pool4.get_shape().as_list()
    reshape = tf.reshape(pool4, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

num_steps = 20001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# WARNING:tensorflow:From <ipython-input-13-f31ece9ca865>:66: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Minibatch loss at step 0: 0.753498
# Minibatch accuracy: 43.8%
# Validation accuracy: 50.0%
# Minibatch loss at step 50: 0.690017
# Minibatch accuracy: 62.5%
# Validation accuracy: 50.0%
# Minibatch loss at step 100: 0.688808
# Minibatch accuracy: 68.8%
# Validation accuracy: 49.7%
# Minibatch loss at step 150: 0.690140
# Minibatch accuracy: 56.2%
# Validation accuracy: 51.2%
# Minibatch loss at step 200: 0.698911
# Minibatch accuracy: 43.8%
# Validation accuracy: 50.0%
# Minibatch loss at step 250: 0.684948
# Minibatch accuracy: 50.0%
# Validation accuracy: 52.8%
# Minibatch loss at step 300: 0.698988
# Minibatch accuracy: 37.5%
# Validation accuracy: 55.5%
# Minibatch loss at step 350: 0.690309
# Minibatch accuracy: 37.5%
# Validation accuracy: 52.5%
# Minibatch loss at step 400: 0.755382
# Minibatch accuracy: 43.8%
# Validation accuracy: 55.2%
# Minibatch loss at step 450: 0.638034
# Minibatch accuracy: 68.8%
# Validation accuracy: 50.2%
# Minibatch loss at step 500: 0.691612
# Minibatch accuracy: 50.0%
# Validation accuracy: 51.3%
# Minibatch loss at step 550: 0.701066
# Minibatch accuracy: 43.8%
# Validation accuracy: 51.5%
# Minibatch loss at step 600: 0.719731
# Minibatch accuracy: 37.5%
# Validation accuracy: 59.0%
# Minibatch loss at step 650: 0.731744
# Minibatch accuracy: 56.2%
# Validation accuracy: 62.7%
# Minibatch loss at step 700: 0.834966
# Minibatch accuracy: 37.5%
# Validation accuracy: 56.8%
# Minibatch loss at step 750: 0.642400
# Minibatch accuracy: 56.2%
# Validation accuracy: 65.2%
# Minibatch loss at step 800: 0.562457
# Minibatch accuracy: 81.2%
# Validation accuracy: 67.5%
# Minibatch loss at step 850: 0.671921
# Minibatch accuracy: 50.0%
# Validation accuracy: 69.0%
# Minibatch loss at step 900: 0.397973
# Minibatch accuracy: 87.5%
# Validation accuracy: 70.5%
# Minibatch loss at step 950: 0.426408
# Minibatch accuracy: 75.0%
# Validation accuracy: 73.5%
# Minibatch loss at step 1000: 0.747020
# Minibatch accuracy: 62.5%
# Validation accuracy: 75.0%
# Minibatch loss at step 1050: 0.457219
# Minibatch accuracy: 75.0%
# Validation accuracy: 74.5%
# Minibatch loss at step 1100: 0.351665
# Minibatch accuracy: 81.2%
# Validation accuracy: 64.5%
# Minibatch loss at step 1150: 0.508520
# Minibatch accuracy: 75.0%
# Validation accuracy: 73.7%
# Minibatch loss at step 1200: 0.262609
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.2%
# Minibatch loss at step 1250: 0.796171
# Minibatch accuracy: 68.8%
# Validation accuracy: 74.7%
# Minibatch loss at step 1300: 0.692297
# Minibatch accuracy: 68.8%
# Validation accuracy: 79.5%
# Minibatch loss at step 1350: 0.273339
# Minibatch accuracy: 87.5%
# Validation accuracy: 70.8%
# Minibatch loss at step 1400: 0.658323
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.7%
# Minibatch loss at step 1450: 0.423015
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.2%
# Minibatch loss at step 1500: 0.167810
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.3%
# Minibatch loss at step 1550: 0.295848
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.7%
# Minibatch loss at step 1600: 0.344328
# Minibatch accuracy: 87.5%
# Validation accuracy: 76.7%
# Minibatch loss at step 1650: 0.288002
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.5%
# Minibatch loss at step 1700: 0.274180
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.2%
# Minibatch loss at step 1750: 0.416727
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.8%
# Minibatch loss at step 1800: 0.287825
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.2%
# Minibatch loss at step 1850: 0.230885
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.5%
# Minibatch loss at step 1900: 0.038686
# Minibatch accuracy: 100.0%
# Validation accuracy: 81.0%
# Minibatch loss at step 1950: 0.173358
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.2%
# Minibatch loss at step 2000: 0.253951
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.7%
# Minibatch loss at step 2050: 0.260748
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.3%
# Minibatch loss at step 2100: 0.048975
# Minibatch accuracy: 100.0%
# Validation accuracy: 81.2%
# Minibatch loss at step 2150: 0.145982
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.0%
# Minibatch loss at step 2200: 0.188520
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.0%
# Minibatch loss at step 2250: 0.177973
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.7%
# Minibatch loss at step 2300: 0.185622
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.5%
# Minibatch loss at step 2350: 0.252836
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.3%
# Minibatch loss at step 2400: 0.182954
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.2%
# Minibatch loss at step 2450: 0.269201
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.5%
# Minibatch loss at step 2500: 0.157056
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.8%
# Minibatch loss at step 2550: 0.099682
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.0%
# Minibatch loss at step 2600: 0.111888
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.5%
# Minibatch loss at step 2650: 0.017899
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.2%
# Minibatch loss at step 2700: 0.196682
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.3%
# Minibatch loss at step 2750: 0.178689
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.7%
# Minibatch loss at step 2800: 0.068639
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.7%
# Minibatch loss at step 2850: 0.018614
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.8%
# Minibatch loss at step 2900: 0.028546
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.2%
# Minibatch loss at step 2950: 0.041914
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.8%
# Minibatch loss at step 3000: 0.107030
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.5%
# Minibatch loss at step 3050: 0.037361
# Minibatch accuracy: 100.0%
# Validation accuracy: 81.7%
# Minibatch loss at step 3100: 0.374371
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.7%
# Minibatch loss at step 3150: 0.012438
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.5%
# Minibatch loss at step 3200: 0.050910
# Minibatch accuracy: 100.0%
# Validation accuracy: 81.3%
# Minibatch loss at step 3250: 0.264490
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.8%
# Minibatch loss at step 3300: 0.147918
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.2%
# Minibatch loss at step 3350: 0.182423
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.5%
# Minibatch loss at step 3400: 0.032148
# Minibatch accuracy: 100.0%
# Validation accuracy: 81.7%
# Minibatch loss at step 3450: 0.026136
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.8%
# Minibatch loss at step 3500: 0.092794
# Minibatch accuracy: 100.0%
# Validation accuracy: 81.8%
# Minibatch loss at step 3550: 0.005775
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.2%
# Minibatch loss at step 3600: 0.014965
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.0%
# Minibatch loss at step 3650: 0.007617
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 3700: 0.037016
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.3%
# Minibatch loss at step 3750: 0.044875
# Minibatch accuracy: 100.0%
# Validation accuracy: 78.8%
# Minibatch loss at step 3800: 0.006893
# Minibatch accuracy: 100.0%
# Validation accuracy: 81.5%
# Minibatch loss at step 3850: 0.002333
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 3900: 0.010906
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.0%
# Minibatch loss at step 3950: 0.002410
# Minibatch accuracy: 100.0%
# Validation accuracy: 81.0%
# Minibatch loss at step 4000: 0.016473
# Minibatch accuracy: 100.0%
# Validation accuracy: 81.7%
# Minibatch loss at step 4050: 0.033352
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 4100: 0.354963
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.0%
# Minibatch loss at step 4150: 0.040303
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 4200: 0.007044
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.0%
# Minibatch loss at step 4250: 0.026712
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.3%
# Minibatch loss at step 4300: 0.078435
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.8%
# Minibatch loss at step 4350: 0.006599
# Minibatch accuracy: 100.0%
# Validation accuracy: 81.2%
# Minibatch loss at step 4400: 0.002147
# Minibatch accuracy: 100.0%
# Validation accuracy: 81.5%
# Minibatch loss at step 4450: 0.013293
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.7%
# Minibatch loss at step 4500: 0.053835
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 4550: 0.023238
# Minibatch accuracy: 100.0%
# Validation accuracy: 81.3%
# Minibatch loss at step 4600: 0.001740
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.2%
# Minibatch loss at step 4650: 0.024939
# Minibatch accuracy: 100.0%
# Validation accuracy: 81.8%
# Minibatch loss at step 4700: 0.011152
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.0%
# Minibatch loss at step 4750: 0.002216
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.3%
# Minibatch loss at step 4800: 0.017495
# Minibatch accuracy: 100.0%
# Validation accuracy: 81.5%
# Minibatch loss at step 4850: 0.012279
# Minibatch accuracy: 100.0%
# Validation accuracy: 81.2%
# Minibatch loss at step 4900: 0.014555
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.0%
# Minibatch loss at step 4950: 0.032488
# Minibatch accuracy: 100.0%
# Validation accuracy: 81.7%
# Minibatch loss at step 5000: 0.001014
# Minibatch accuracy: 100.0%
# Validation accuracy: 81.5%
# Minibatch loss at step 5050: 0.008468
# Minibatch accuracy: 100.0%
# Validation accuracy: 81.7%
# Minibatch loss at step 5100: 0.002819
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.3%
# Minibatch loss at step 5150: 0.011017
# Minibatch accuracy: 100.0%
# Validation accuracy: 81.2%
# Minibatch loss at step 5200: 0.033182
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.0%
# Minibatch loss at step 5250: 0.002927
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 5300: 0.003091
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 5350: 0.013320
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.2%
# Minibatch loss at step 5400: 0.004646
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 5450: 0.000595
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.3%
# Minibatch loss at step 5500: 0.000797
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.0%
# Minibatch loss at step 5550: 0.001682
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.3%
# Minibatch loss at step 5600: 0.000366
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.3%
# Minibatch loss at step 5650: 0.000693
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 5700: 0.003086
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.3%
# Minibatch loss at step 5750: 0.000495
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.2%
# Minibatch loss at step 5800: 0.000132
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 5850: 0.000411
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 5900: 0.000756
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 5950: 0.002565
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 6000: 0.002567
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 6050: 0.000153
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 6100: 0.000128
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 6150: 0.000368
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 6200: 0.000906
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 6250: 0.000046
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 6300: 0.000932
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 6350: 0.000099
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 6400: 0.000824
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 6450: 0.001004
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 6500: 0.000202
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 6550: 0.000180
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 6600: 0.000662
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 6650: 0.000204
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 6700: 0.000040
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.3%
# Minibatch loss at step 6750: 0.000685
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 6800: 0.000103
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 6850: 0.000281
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 6900: 0.000448
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.3%
# Minibatch loss at step 6950: 0.000258
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 7000: 0.000465
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 7050: 0.000607
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.3%
# Minibatch loss at step 7100: 0.000063
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 7150: 0.000336
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 7200: 0.000003
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.3%
# Minibatch loss at step 7250: 0.000916
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 7300: 0.000308
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 7350: 0.000327
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.3%
# Minibatch loss at step 7400: 0.001800
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.3%
# Minibatch loss at step 7450: 0.000187
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 7500: 0.001069
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.3%
# Minibatch loss at step 7550: 0.000116
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 7600: 0.000172
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 7650: 0.000074
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.3%
# Minibatch loss at step 7700: 0.000924
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.3%
# Minibatch loss at step 7750: 0.000519
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 7800: 0.000034
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.3%
# Minibatch loss at step 7850: 0.000198
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.3%
# Minibatch loss at step 7900: 0.000618
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 7950: 0.000283
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.3%
# Minibatch loss at step 8000: 0.000165
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.3%
# Minibatch loss at step 8050: 0.000519
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.2%
# Minibatch loss at step 8100: 0.000036
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.3%
# Minibatch loss at step 8150: 0.000100
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.3%
# Minibatch loss at step 8200: 0.000023
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.2%
# Minibatch loss at step 8250: 0.000445
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.3%
# Minibatch loss at step 8300: 0.000317
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.3%
# Minibatch loss at step 8350: 0.000023
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.2%
# Minibatch loss at step 8400: 0.000140
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.3%
# Minibatch loss at step 8450: 0.000338
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.2%
# Minibatch loss at step 8500: 0.000011
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.2%
# Minibatch loss at step 8550: 0.000133
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.3%
# Minibatch loss at step 8600: 0.000440
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.2%
# Minibatch loss at step 8650: 0.000075
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.3%
# Minibatch loss at step 8700: 0.000259
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.3%
# Minibatch loss at step 8750: 0.000842
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.2%
# Minibatch loss at step 8800: 0.000235
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.3%
# Minibatch loss at step 8850: 0.000060
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 8900: 0.000937
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.2%
# Minibatch loss at step 8950: 0.000207
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 9000: 0.000088
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 9050: 0.000187
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.2%
# Minibatch loss at step 9100: 0.000744
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 9150: 0.000087
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 9200: 0.000019
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.3%
# Minibatch loss at step 9250: 0.000333
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 9300: 0.000446
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 9350: 0.000035
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.2%
# Minibatch loss at step 9400: 0.000038
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 9450: 0.000115
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 9500: 0.000395
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 9550: 0.000020
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 9600: 0.000047
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 9650: 0.000059
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 9700: 0.000161
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 9750: 0.000407
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 9800: 0.000169
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 9850: 0.000129
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 9900: 0.000194
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 9950: 0.000099
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 10000: 0.000015
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 10050: 0.000019
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 10100: 0.000010
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 10150: 0.000159
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 10200: 0.000130
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 10250: 0.000158
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 10300: 0.000081
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 10350: 0.000058
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 10400: 0.000103
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 10450: 0.000195
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 10500: 0.000309
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 10550: 0.000160
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 10600: 0.000050
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 10650: 0.000105
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 10700: 0.000121
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 10750: 0.000238
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 10800: 0.000226
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 10850: 0.000003
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 10900: 0.000294
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 10950: 0.000302
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 11000: 0.000001
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 11050: 0.000307
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 11100: 0.000002
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 11150: 0.000017
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 11200: 0.000325
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 11250: 0.000176
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 11300: 0.000114
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 11350: 0.000248
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 11400: 0.000006
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 11450: 0.000006
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 11500: 0.000171
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 11550: 0.000496
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.0%
# Minibatch loss at step 11600: 0.000316
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 11650: 0.000050
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 11700: 0.000127
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.0%
# Minibatch loss at step 11750: 0.000092
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 11800: 0.000012
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 11850: 0.000021
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.0%
# Minibatch loss at step 11900: 0.000177
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 11950: 0.000141
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 12000: 0.000156
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.0%
# Minibatch loss at step 12050: 0.000035
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 12100: 0.000133
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.0%
# Minibatch loss at step 12150: 0.000087
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.0%
# Minibatch loss at step 12200: 0.000190
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 12250: 0.000174
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.0%
# Minibatch loss at step 12300: 0.000066
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.0%
# Minibatch loss at step 12350: 0.000140
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 12400: 0.000299
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.0%
# Minibatch loss at step 12450: 0.000057
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.0%
# Minibatch loss at step 12500: 0.000065
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 12550: 0.000095
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.0%
# Minibatch loss at step 12600: 0.000103
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 12650: 0.000336
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 12700: 0.000066
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 12750: 0.000067
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 12800: 0.000097
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 12850: 0.000149
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 12900: 0.000014
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 12950: 0.000065
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 13000: 0.000099
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 13050: 0.000075
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 13100: 0.000082
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 13150: 0.000066
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 13200: 0.000075
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 13250: 0.000018
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 13300: 0.000053
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 13350: 0.000046
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 13400: 0.000267
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 13450: 0.000170
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 13500: 0.000030
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 13550: 0.000030
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 13600: 0.000041
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 13650: 0.000149
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 13700: 0.000005
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 13750: 0.000104
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 13800: 0.000020
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 13850: 0.000139
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 13900: 0.000145
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 13950: 0.000047
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 14000: 0.000080
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 14050: 0.000079
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 14100: 0.000052
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 14150: 0.000007
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 14200: 0.000156
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 14250: 0.000031
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 14300: 0.000087
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 14350: 0.000085
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 14400: 0.000051
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 14450: 0.000107
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 14500: 0.000166
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 14550: 0.000012
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 14600: 0.000080
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 14650: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 14700: 0.000172
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 14750: 0.000088
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 14800: 0.000100
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 14850: 0.000384
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 14900: 0.000035
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 14950: 0.000270
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 15000: 0.000022
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 15050: 0.000061
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 15100: 0.000021
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 15150: 0.000191
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 15200: 0.000120
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 15250: 0.000015
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 15300: 0.000051
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 15350: 0.000209
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 15400: 0.000068
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 15450: 0.000043
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 15500: 0.000109
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 15550: 0.000013
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 15600: 0.000041
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 15650: 0.000007
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 15700: 0.000118
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 15750: 0.000076
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 15800: 0.000009
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 15850: 0.000043
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 15900: 0.000071
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 15950: 0.000003
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 16000: 0.000041
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 16050: 0.000123
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 16100: 0.000017
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 16150: 0.000096
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 16200: 0.000250
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 16250: 0.000076
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 16300: 0.000016
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 16350: 0.000344
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 16400: 0.000049
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 16450: 0.000040
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 16500: 0.000057
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 16550: 0.000252
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 16600: 0.000035
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 16650: 0.000007
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 16700: 0.000105
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 16750: 0.000162
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 16800: 0.000012
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 16850: 0.000017
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 16900: 0.000057
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 16950: 0.000135
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 17000: 0.000007
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 17050: 0.000023
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 17100: 0.000022
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 17150: 0.000064
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 17200: 0.000163
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 17250: 0.000061
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 17300: 0.000057
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 17350: 0.000086
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 17400: 0.000041
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 17450: 0.000008
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 17500: 0.000006
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 17550: 0.000004
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 17600: 0.000070
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 17650: 0.000051
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 17700: 0.000075
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 17750: 0.000029
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 17800: 0.000018
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 17850: 0.000049
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 17900: 0.000078
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 17950: 0.000114
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 18000: 0.000061
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 18050: 0.000022
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 18100: 0.000042
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 18150: 0.000069
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 18200: 0.000109
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 18250: 0.000099
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 18300: 0.000001
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 18350: 0.000117
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 18400: 0.000122
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 18450: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 18500: 0.000120
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 18550: 0.000001
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 18600: 0.000008
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 18650: 0.000148
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 18700: 0.000076
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 18750: 0.000049
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 18800: 0.000100
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 18850: 0.000003
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 18900: 0.000004
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 18950: 0.000077
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 19000: 0.000214
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 19050: 0.000135
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 19100: 0.000024
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 19150: 0.000056
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 19200: 0.000054
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 19250: 0.000005
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 19300: 0.000009
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 19350: 0.000078
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 19400: 0.000064
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 19450: 0.000071
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 19500: 0.000019
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 19550: 0.000060
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 19600: 0.000041
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 19650: 0.000081
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 19700: 0.000083
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 19750: 0.000033
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 19800: 0.000065
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 19850: 0.000140
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 19900: 0.000028
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 19950: 0.000036
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 20000: 0.000047
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Test accuracy: 83.0%

# %% [markdown]
# The next version we'll build a model inspired by VGG16 architecture:
# * conv1_1 + ReLU - 64x64x32
# * conv1_2 + ReLU - 64x64x32
# * MP1 - 32x32x32
# * conv2_1 + ReLU - 32x32x64
# * conv2_2 + ReLU - 32x32x64
# * MP2 - 16x16x64
# * conv3_1 + ReLU - 16x16x128
# * conv3_2 + ReLU - 16x16x128
# * conv3_3 + ReLU - 16x16x128
# * MP3 - 8x8x128
# * conv4_1 + ReLU - 8x8x256
# * conv4_2 + ReLU - 8x8x256
# * conv4_3 + ReLU - 8x8x256
# * MP4 - 4x4x256
# * FC 4096 + ReLU
# * FC 4096x1000 + ReLU
# * FC 1000x2 + softmax

# %%
batch_size = 16
patch_size = 3
drop_out = 0.5

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  global_step = tf.Variable(0)
  
  # Variables
  layer1_1weights = tf.Variable(tf.truncated_normal(
      [3, 3, 3, 32], stddev=0.1)) 
  layer1_1biases = tf.Variable(tf.zeros([32]))

  layer1_2weights = tf.Variable(tf.truncated_normal(
      [3, 3, 32, 32], stddev=0.1))
  layer1_2biases = tf.Variable(tf.constant(1.0, shape=[32]))
  
  layer2_1weights = tf.Variable(tf.truncated_normal(
      [3, 3, 32, 64], stddev=0.1))
  layer2_1biases = tf.Variable(tf.constant(1.0, shape=[64]))

  layer2_2weights = tf.Variable(tf.truncated_normal(
      [3, 3, 64, 64], stddev=0.1))
  layer2_2biases = tf.Variable(tf.constant(1.0, shape=[64]))

  layer3_1weights = tf.Variable(tf.truncated_normal(
      [3, 3, 64, 128], stddev=0.1))
  layer3_1biases = tf.Variable(tf.constant(1.0, shape=[128]))

  layer3_2weights = tf.Variable(tf.truncated_normal(
      [3, 3, 128, 128], stddev=0.1))
  layer3_2biases = tf.Variable(tf.constant(1.0, shape=[128]))

  layer3_3weights = tf.Variable(tf.truncated_normal(
      [3, 3, 128, 128], stddev=0.1))
  layer3_3biases = tf.Variable(tf.constant(1.0, shape=[128]))

  layer4_1weights = tf.Variable(tf.truncated_normal(
      [3, 3, 128, 256], stddev=0.1))
  layer4_1biases = tf.Variable(tf.constant(1.0, shape=[256]))

  layer4_2weights = tf.Variable(tf.truncated_normal(
      [3, 3, 256, 256], stddev=0.1))
  layer4_2biases = tf.Variable(tf.constant(1.0, shape=[256]))

  layer4_3weights = tf.Variable(tf.truncated_normal(
      [3, 3, 256, 256], stddev=0.1))
  layer4_3biases = tf.Variable(tf.constant(1.0, shape=[256]))

  # big_shape = image_size // 4 * image_size // 4 * image_size // 4 * image_size // 4 * 512
  big_shape = 4096

  fc1w = tf.Variable(tf.truncated_normal(
      [big_shape, 4096], dtype=tf.float32, stddev=0.1))
  fc1b = tf.Variable(tf.constant(1.0, shape=[4096], dtype=tf.float32))

#   fc2w = tf.Variable(tf.truncated_normal(
#     [4096, 4096], dtype=tf.float32, stddev=0.1))
#   fc2b = tf.Variable(tf.constant(1.0, shape=[4096], dtype=tf.float32))

#   fc3w = tf.Variable(tf.truncated_normal(
#       [4096, 1000], dtype=tf.float32, stddev=0.1))
#   fc3b = tf.Variable(tf.constant(1.0, shape=[1000], dtype=tf.float32))
  
  fc4w = tf.Variable(tf.truncated_normal(
      [4096, 2], dtype=tf.float32, stddev=0.1))
  fc4b = tf.Variable(tf.constant(1.0, shape=[2], dtype=tf.float32))
  
  # Model.
  def model(data, keep_prob):
    # conv1
    conv1_1 = tf.nn.conv2d(data, layer1_1weights, [1,1,1,1], padding='SAME')    
    bias1_1 = tf.nn.relu(conv1_1 + layer1_1biases)

    conv1_2 = tf.nn.conv2d(bias1_1, layer1_2weights, [1,1,1,1], padding='SAME')    
    bias1_2 = tf.nn.relu(conv1_2 + layer1_2biases)
    
    pool1 = tf.nn.max_pool(bias1_2, [1,2,2,1], [1,2,2,1], padding='SAME')

    # conv2
    conv2_1 = tf.nn.conv2d(pool1, layer2_1weights, [1,1,1,1], padding='SAME')    
    bias2_1 = tf.nn.relu(conv2_1 + layer2_1biases)

    conv2_2 = tf.nn.conv2d(bias2_1, layer2_2weights, [1,1,1,1], padding='SAME')    
    bias2_2 = tf.nn.relu(conv2_2 + layer2_2biases)
    
    pool2 = tf.nn.max_pool(bias2_2, [1,2,2,1], [1,2,2,1], padding='SAME')

    # conv3
    conv3_1 = tf.nn.conv2d(pool2, layer3_1weights, [1,1,1,1], padding='SAME')    
    bias3_1 = tf.nn.relu(conv3_1 + layer3_1biases)

    conv3_2 = tf.nn.conv2d(bias3_1, layer3_2weights, [1,1,1,1], padding='SAME')    
    bias3_2 = tf.nn.relu(conv3_2 + layer3_2biases)

    conv3_3 = tf.nn.conv2d(bias3_2, layer3_3weights, [1,1,1,1], padding='SAME')    
    bias3_3 = tf.nn.relu(conv3_3 + layer3_3biases)
    
    pool3 = tf.nn.max_pool(bias3_3, [1,2,2,1], [1,2,2,1], padding='SAME')

    # conv4
    conv4_1 = tf.nn.conv2d(pool3, layer4_1weights, [1,1,1,1], padding='SAME')    
    bias4_1 = tf.nn.relu(conv4_1 + layer4_1biases)

    conv4_2 = tf.nn.conv2d(bias4_1, layer4_2weights, [1,1,1,1], padding='SAME')    
    bias4_2 = tf.nn.relu(conv4_2 + layer4_2biases)

    conv4_3 = tf.nn.conv2d(bias4_2, layer4_3weights, [1,1,1,1], padding='SAME')    
    bias4_3 = tf.nn.relu(conv4_3 + layer4_3biases)
    
    pool4 = tf.nn.max_pool(bias4_3, [1,2,2,1], [1,2,2,1], padding='SAME')
    
    # shape = int(np.prod(pool4.get_shape()[1:]))
    shape = int(np.prod(pool4.get_shape()[1:]))

    # fully-connected layer
    # fc1
    # fc1w = tf.Variable(tf.truncated_normal(
    #   [shape, 4096], dtype=tf.float32, stddev=0.1))
    # fc1b = tf.Variable(tf.constant(1.0, shape=[4096], dtype=tf.float32))
    # pool4_flat = tf.reshape(pool4, [-1, shape])    
    # fc1 = tf.nn.relu(tf.matmul(pool4_flat, fc1w) + fc1b)
    pool3_flat = tf.reshape(pool4, [-1, shape])    
    fc1 = tf.nn.relu(tf.matmul(pool3_flat, fc1w) + fc1b)
    drop1 = tf.nn.dropout(fc1, keep_prob)

    # fc2
    # fc2w = tf.Variable(tf.truncated_normal(
    #   [4096, 4096], dtype=tf.float32, stddev=0.1))
    # fc2b = tf.Variable(tf.constant(1.0, shape=[4096], dtype=tf.float32))
#     fc2 = tf.nn.relu(tf.matmul(drop1, fc2w) + fc2b)
#     drop2 = tf.nn.dropout(fc2, keep_prob)

    # fc3
    # fc3w = tf.Variable(tf.truncated_normal(
    #   [4096, 1000], dtype=tf.float32, stddev=0.1))
    # fc3b = tf.Variable(tf.constant(1.0, shape=[1000], dtype=tf.float32))
    # fc3 = tf.nn.relu(tf.matmul(fc2, fc3w) + fc3b)
#     fc3 = tf.nn.relu(tf.matmul(drop1, fc3w) + fc3b)
#     drop3 = tf.nn.dropout(fc3, keep_prob)

    # fc4
    # fc4w = tf.Variable(tf.truncated_normal(
    #   [1000, 2], dtype=tf.float32, stddev=0.1))
    # fc4b = tf.Variable(tf.constant(1.0, shape=[2], dtype=tf.float32))
    return tf.matmul(drop1, fc4w) + fc4b
  
  # Training computation.
  logits = model(tf_train_dataset, drop_out)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  learning_rate = tf.train.exponential_decay(1e-5, global_step, 1000, 0.85, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset, 1.0))
  test_prediction = tf.nn.softmax(model(tf_test_dataset, 1.0))

num_steps = 20001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# WARNING:tensorflow:From <ipython-input-14-92758c078353>:173: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Minibatch loss at step 0: 9053.697266
# Minibatch accuracy: 43.8%
# Validation accuracy: 50.0%
# Minibatch loss at step 50: 105.559616
# Minibatch accuracy: 75.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 100: 88.181213
# Minibatch accuracy: 75.0%
# Validation accuracy: 53.8%
# Minibatch loss at step 150: 145.402328
# Minibatch accuracy: 37.5%
# Validation accuracy: 50.2%
# Minibatch loss at step 200: 61.735985
# Minibatch accuracy: 50.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 250: 107.448715
# Minibatch accuracy: 56.2%
# Validation accuracy: 57.0%
# Minibatch loss at step 300: 125.309151
# Minibatch accuracy: 62.5%
# Validation accuracy: 52.8%
# Minibatch loss at step 350: 112.465195
# Minibatch accuracy: 50.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 400: 36.631924
# Minibatch accuracy: 62.5%
# Validation accuracy: 57.7%
# Minibatch loss at step 450: 46.620186
# Minibatch accuracy: 62.5%
# Validation accuracy: 60.8%
# Minibatch loss at step 500: 89.337173
# Minibatch accuracy: 43.8%
# Validation accuracy: 53.3%
# Minibatch loss at step 550: 48.598289
# Minibatch accuracy: 50.0%
# Validation accuracy: 56.0%
# Minibatch loss at step 600: 67.484268
# Minibatch accuracy: 62.5%
# Validation accuracy: 50.5%
# Minibatch loss at step 650: 55.324165
# Minibatch accuracy: 56.2%
# Validation accuracy: 51.3%
# Minibatch loss at step 700: 47.626816
# Minibatch accuracy: 43.8%
# Validation accuracy: 55.3%
# Minibatch loss at step 750: 36.795158
# Minibatch accuracy: 56.2%
# Validation accuracy: 60.5%
# Minibatch loss at step 800: 51.307129
# Minibatch accuracy: 43.8%
# Validation accuracy: 58.5%
# Minibatch loss at step 850: 21.274311
# Minibatch accuracy: 68.8%
# Validation accuracy: 56.3%
# Minibatch loss at step 900: 17.693188
# Minibatch accuracy: 75.0%
# Validation accuracy: 60.8%
# Minibatch loss at step 950: 50.001545
# Minibatch accuracy: 37.5%
# Validation accuracy: 60.8%
# Minibatch loss at step 1000: 28.456886
# Minibatch accuracy: 56.2%
# Validation accuracy: 63.0%
# Minibatch loss at step 1050: 48.244576
# Minibatch accuracy: 37.5%
# Validation accuracy: 56.3%
# Minibatch loss at step 1100: 38.727257
# Minibatch accuracy: 50.0%
# Validation accuracy: 60.0%
# Minibatch loss at step 1150: 31.597275
# Minibatch accuracy: 43.8%
# Validation accuracy: 60.0%
# Minibatch loss at step 1200: 36.536251
# Minibatch accuracy: 37.5%
# Validation accuracy: 64.5%
# Minibatch loss at step 1250: 16.048979
# Minibatch accuracy: 62.5%
# Validation accuracy: 58.0%
# Minibatch loss at step 1300: 34.855682
# Minibatch accuracy: 43.8%
# Validation accuracy: 60.7%
# Minibatch loss at step 1350: 15.828150
# Minibatch accuracy: 68.8%
# Validation accuracy: 62.3%
# Minibatch loss at step 1400: 47.382679
# Minibatch accuracy: 31.2%
# Validation accuracy: 63.7%
# Minibatch loss at step 1450: 25.948519
# Minibatch accuracy: 37.5%
# Validation accuracy: 58.5%
# Minibatch loss at step 1500: 19.506123
# Minibatch accuracy: 56.2%
# Validation accuracy: 52.0%
# Minibatch loss at step 1550: 20.140326
# Minibatch accuracy: 75.0%
# Validation accuracy: 57.2%
# Minibatch loss at step 1600: 20.147501
# Minibatch accuracy: 68.8%
# Validation accuracy: 64.3%
# Minibatch loss at step 1650: 23.187466
# Minibatch accuracy: 68.8%
# Validation accuracy: 63.7%
# Minibatch loss at step 1700: 10.609181
# Minibatch accuracy: 75.0%
# Validation accuracy: 63.3%
# Minibatch loss at step 1750: 5.822545
# Minibatch accuracy: 81.2%
# Validation accuracy: 65.0%
# Minibatch loss at step 1800: 28.164368
# Minibatch accuracy: 50.0%
# Validation accuracy: 67.7%
# Minibatch loss at step 1850: 19.386862
# Minibatch accuracy: 62.5%
# Validation accuracy: 65.0%
# Minibatch loss at step 1900: 27.107761
# Minibatch accuracy: 43.8%
# Validation accuracy: 64.8%
# Minibatch loss at step 1950: 19.402653
# Minibatch accuracy: 50.0%
# Validation accuracy: 62.0%
# Minibatch loss at step 2000: 12.790906
# Minibatch accuracy: 68.8%
# Validation accuracy: 68.2%
# Minibatch loss at step 2050: 6.765648
# Minibatch accuracy: 68.8%
# Validation accuracy: 56.2%
# Minibatch loss at step 2100: 17.572687
# Minibatch accuracy: 56.2%
# Validation accuracy: 59.5%
# Minibatch loss at step 2150: 10.908117
# Minibatch accuracy: 62.5%
# Validation accuracy: 68.2%
# Minibatch loss at step 2200: 21.345329
# Minibatch accuracy: 56.2%
# Validation accuracy: 66.5%
# Minibatch loss at step 2250: 21.883173
# Minibatch accuracy: 56.2%
# Validation accuracy: 59.3%
# Minibatch loss at step 2300: 15.372101
# Minibatch accuracy: 56.2%
# Validation accuracy: 67.8%
# Minibatch loss at step 2350: 16.350086
# Minibatch accuracy: 37.5%
# Validation accuracy: 67.5%
# Minibatch loss at step 2400: 15.802673
# Minibatch accuracy: 62.5%
# Validation accuracy: 67.0%
# Minibatch loss at step 2450: 22.589130
# Minibatch accuracy: 50.0%
# Validation accuracy: 62.3%
# Minibatch loss at step 2500: 7.388700
# Minibatch accuracy: 62.5%
# Validation accuracy: 68.0%
# Minibatch loss at step 2550: 17.805794
# Minibatch accuracy: 56.2%
# Validation accuracy: 67.7%
# Minibatch loss at step 2600: 14.645493
# Minibatch accuracy: 50.0%
# Validation accuracy: 66.3%
# Minibatch loss at step 2650: 12.400454
# Minibatch accuracy: 56.2%
# Validation accuracy: 61.3%
# Minibatch loss at step 2700: 12.435626
# Minibatch accuracy: 62.5%
# Validation accuracy: 67.5%
# Minibatch loss at step 2750: 12.100325
# Minibatch accuracy: 75.0%
# Validation accuracy: 67.8%
# Minibatch loss at step 2800: 12.204574
# Minibatch accuracy: 62.5%
# Validation accuracy: 65.3%
# Minibatch loss at step 2850: 13.162745
# Minibatch accuracy: 68.8%
# Validation accuracy: 68.7%
# Minibatch loss at step 2900: 13.901120
# Minibatch accuracy: 43.8%
# Validation accuracy: 67.5%
# Minibatch loss at step 2950: 17.296993
# Minibatch accuracy: 56.2%
# Validation accuracy: 66.5%
# Minibatch loss at step 3000: 6.083462
# Minibatch accuracy: 56.2%
# Validation accuracy: 64.5%
# Minibatch loss at step 3050: 11.373031
# Minibatch accuracy: 50.0%
# Validation accuracy: 68.7%
# Minibatch loss at step 3100: 7.713159
# Minibatch accuracy: 68.8%
# Validation accuracy: 69.0%
# Minibatch loss at step 3150: 16.120850
# Minibatch accuracy: 37.5%
# Validation accuracy: 70.0%
# Minibatch loss at step 3200: 6.113993
# Minibatch accuracy: 75.0%
# Validation accuracy: 68.2%
# Minibatch loss at step 3250: 10.806991
# Minibatch accuracy: 43.8%
# Validation accuracy: 65.0%
# Minibatch loss at step 3300: 22.036463
# Minibatch accuracy: 31.2%
# Validation accuracy: 67.5%
# Minibatch loss at step 3350: 24.512066
# Minibatch accuracy: 31.2%
# Validation accuracy: 60.8%
# Minibatch loss at step 3400: 7.405626
# Minibatch accuracy: 62.5%
# Validation accuracy: 64.2%
# Minibatch loss at step 3450: 11.369624
# Minibatch accuracy: 43.8%
# Validation accuracy: 67.8%
# Minibatch loss at step 3500: 12.203687
# Minibatch accuracy: 68.8%
# Validation accuracy: 61.0%
# Minibatch loss at step 3550: 6.339822
# Minibatch accuracy: 68.8%
# Validation accuracy: 66.0%
# Minibatch loss at step 3600: 19.753975
# Minibatch accuracy: 62.5%
# Validation accuracy: 68.5%
# Minibatch loss at step 3650: 9.936510
# Minibatch accuracy: 56.2%
# Validation accuracy: 71.3%
# Minibatch loss at step 3700: 16.898157
# Minibatch accuracy: 43.8%
# Validation accuracy: 70.0%
# Minibatch loss at step 3750: 6.643243
# Minibatch accuracy: 62.5%
# Validation accuracy: 66.8%
# Minibatch loss at step 3800: 5.569009
# Minibatch accuracy: 81.2%
# Validation accuracy: 66.0%
# Minibatch loss at step 3850: 9.763515
# Minibatch accuracy: 56.2%
# Validation accuracy: 68.3%
# Minibatch loss at step 3900: 12.835206
# Minibatch accuracy: 56.2%
# Validation accuracy: 69.0%
# Minibatch loss at step 3950: 2.643637
# Minibatch accuracy: 87.5%
# Validation accuracy: 68.3%
# Minibatch loss at step 4000: 9.443513
# Minibatch accuracy: 62.5%
# Validation accuracy: 70.3%
# Minibatch loss at step 4050: 8.461113
# Minibatch accuracy: 75.0%
# Validation accuracy: 71.0%
# Minibatch loss at step 4100: 12.266354
# Minibatch accuracy: 56.2%
# Validation accuracy: 67.8%
# Minibatch loss at step 4150: 5.429645
# Minibatch accuracy: 75.0%
# Validation accuracy: 71.2%
# Minibatch loss at step 4200: 7.240005
# Minibatch accuracy: 56.2%
# Validation accuracy: 69.8%
# Minibatch loss at step 4250: 12.795739
# Minibatch accuracy: 56.2%
# Validation accuracy: 70.8%
# Minibatch loss at step 4300: 13.925344
# Minibatch accuracy: 50.0%
# Validation accuracy: 73.0%
# Minibatch loss at step 4350: 10.722173
# Minibatch accuracy: 56.2%
# Validation accuracy: 72.5%
# Minibatch loss at step 4400: 11.024730
# Minibatch accuracy: 68.8%
# Validation accuracy: 72.8%
# Minibatch loss at step 4450: 12.243237
# Minibatch accuracy: 56.2%
# Validation accuracy: 69.8%
# Minibatch loss at step 4500: 2.454205
# Minibatch accuracy: 81.2%
# Validation accuracy: 71.0%
# Minibatch loss at step 4550: 4.039138
# Minibatch accuracy: 68.8%
# Validation accuracy: 71.0%
# Minibatch loss at step 4600: 6.495162
# Minibatch accuracy: 62.5%
# Validation accuracy: 72.7%
# Minibatch loss at step 4650: 4.309604
# Minibatch accuracy: 62.5%
# Validation accuracy: 71.3%
# Minibatch loss at step 4700: 3.717992
# Minibatch accuracy: 75.0%
# Validation accuracy: 69.8%
# Minibatch loss at step 4750: 10.458608
# Minibatch accuracy: 56.2%
# Validation accuracy: 73.0%
# Minibatch loss at step 4800: 8.597525
# Minibatch accuracy: 68.8%
# Validation accuracy: 72.0%
# Minibatch loss at step 4850: 2.262091
# Minibatch accuracy: 81.2%
# Validation accuracy: 70.0%
# Minibatch loss at step 4900: 6.109260
# Minibatch accuracy: 68.8%
# Validation accuracy: 72.0%
# Minibatch loss at step 4950: 6.056364
# Minibatch accuracy: 81.2%
# Validation accuracy: 73.8%
# Minibatch loss at step 5000: 8.150342
# Minibatch accuracy: 56.2%
# Validation accuracy: 71.2%
# Minibatch loss at step 5050: 6.873189
# Minibatch accuracy: 68.8%
# Validation accuracy: 73.0%
# Minibatch loss at step 5100: 9.204853
# Minibatch accuracy: 62.5%
# Validation accuracy: 70.7%
# Minibatch loss at step 5150: 5.242194
# Minibatch accuracy: 75.0%
# Validation accuracy: 74.8%
# Minibatch loss at step 5200: 8.951734
# Minibatch accuracy: 56.2%
# Validation accuracy: 72.7%
# Minibatch loss at step 5250: 5.460234
# Minibatch accuracy: 62.5%
# Validation accuracy: 74.2%
# Minibatch loss at step 5300: 8.887973
# Minibatch accuracy: 56.2%
# Validation accuracy: 70.7%
# Minibatch loss at step 5350: 6.510080
# Minibatch accuracy: 75.0%
# Validation accuracy: 70.0%
# Minibatch loss at step 5400: 5.049604
# Minibatch accuracy: 75.0%
# Validation accuracy: 71.8%
# Minibatch loss at step 5450: 10.100895
# Minibatch accuracy: 62.5%
# Validation accuracy: 70.2%
# Minibatch loss at step 5500: 1.032823
# Minibatch accuracy: 81.2%
# Validation accuracy: 70.7%
# Minibatch loss at step 5550: 12.001895
# Minibatch accuracy: 62.5%
# Validation accuracy: 73.2%
# Minibatch loss at step 5600: 11.991121
# Minibatch accuracy: 62.5%
# Validation accuracy: 72.8%
# Minibatch loss at step 5650: 5.091155
# Minibatch accuracy: 62.5%
# Validation accuracy: 73.7%
# Minibatch loss at step 5700: 8.586012
# Minibatch accuracy: 56.2%
# Validation accuracy: 72.8%
# Minibatch loss at step 5750: 8.173141
# Minibatch accuracy: 56.2%
# Validation accuracy: 72.3%
# Minibatch loss at step 5800: 4.346205
# Minibatch accuracy: 56.2%
# Validation accuracy: 71.2%
# Minibatch loss at step 5850: 8.888394
# Minibatch accuracy: 56.2%
# Validation accuracy: 75.5%
# Minibatch loss at step 5900: 4.116382
# Minibatch accuracy: 75.0%
# Validation accuracy: 75.0%
# Minibatch loss at step 5950: 4.096215
# Minibatch accuracy: 75.0%
# Validation accuracy: 71.8%
# Minibatch loss at step 6000: 8.793121
# Minibatch accuracy: 62.5%
# Validation accuracy: 71.3%
# Minibatch loss at step 6050: 6.777077
# Minibatch accuracy: 68.8%
# Validation accuracy: 73.2%
# Minibatch loss at step 6100: 8.000544
# Minibatch accuracy: 56.2%
# Validation accuracy: 71.3%
# Minibatch loss at step 6150: 4.172716
# Minibatch accuracy: 81.2%
# Validation accuracy: 72.2%
# Minibatch loss at step 6200: 5.809176
# Minibatch accuracy: 68.8%
# Validation accuracy: 73.3%
# Minibatch loss at step 6250: 3.295864
# Minibatch accuracy: 87.5%
# Validation accuracy: 74.0%
# Minibatch loss at step 6300: 7.035605
# Minibatch accuracy: 50.0%
# Validation accuracy: 68.7%
# Minibatch loss at step 6350: 10.662102
# Minibatch accuracy: 56.2%
# Validation accuracy: 73.0%
# Minibatch loss at step 6400: 3.395542
# Minibatch accuracy: 62.5%
# Validation accuracy: 73.8%
# Minibatch loss at step 6450: 12.969320
# Minibatch accuracy: 68.8%
# Validation accuracy: 72.0%
# Minibatch loss at step 6500: 1.984774
# Minibatch accuracy: 87.5%
# Validation accuracy: 74.5%
# Minibatch loss at step 6550: 3.743728
# Minibatch accuracy: 68.8%
# Validation accuracy: 70.8%
# Minibatch loss at step 6600: 10.193775
# Minibatch accuracy: 62.5%
# Validation accuracy: 73.3%
# Minibatch loss at step 6650: 6.014472
# Minibatch accuracy: 75.0%
# Validation accuracy: 73.7%
# Minibatch loss at step 6700: 3.318259
# Minibatch accuracy: 68.8%
# Validation accuracy: 75.3%
# Minibatch loss at step 6750: 10.332789
# Minibatch accuracy: 75.0%
# Validation accuracy: 72.2%
# Minibatch loss at step 6800: 1.395539
# Minibatch accuracy: 75.0%
# Validation accuracy: 69.7%
# Minibatch loss at step 6850: 3.171243
# Minibatch accuracy: 81.2%
# Validation accuracy: 75.5%
# Minibatch loss at step 6900: 3.632138
# Minibatch accuracy: 68.8%
# Validation accuracy: 74.8%
# Minibatch loss at step 6950: 6.447788
# Minibatch accuracy: 75.0%
# Validation accuracy: 74.5%
# Minibatch loss at step 7000: 0.413981
# Minibatch accuracy: 93.8%
# Validation accuracy: 74.3%
# Minibatch loss at step 7050: 5.264199
# Minibatch accuracy: 81.2%
# Validation accuracy: 73.3%
# Minibatch loss at step 7100: 1.432631
# Minibatch accuracy: 87.5%
# Validation accuracy: 73.5%
# Minibatch loss at step 7150: 10.340569
# Minibatch accuracy: 50.0%
# Validation accuracy: 74.5%
# Minibatch loss at step 7200: 2.590026
# Minibatch accuracy: 81.2%
# Validation accuracy: 75.5%
# Minibatch loss at step 7250: 8.908348
# Minibatch accuracy: 62.5%
# Validation accuracy: 71.3%
# Minibatch loss at step 7300: 4.731765
# Minibatch accuracy: 62.5%
# Validation accuracy: 74.3%
# Minibatch loss at step 7350: 5.046669
# Minibatch accuracy: 62.5%
# Validation accuracy: 73.5%
# Minibatch loss at step 7400: 3.407833
# Minibatch accuracy: 56.2%
# Validation accuracy: 75.2%
# Minibatch loss at step 7450: 3.496065
# Minibatch accuracy: 75.0%
# Validation accuracy: 73.5%
# Minibatch loss at step 7500: 10.276098
# Minibatch accuracy: 50.0%
# Validation accuracy: 73.3%
# Minibatch loss at step 7550: 6.649263
# Minibatch accuracy: 75.0%
# Validation accuracy: 74.2%
# Minibatch loss at step 7600: 4.741230
# Minibatch accuracy: 81.2%
# Validation accuracy: 75.2%
# Minibatch loss at step 7650: 2.107152
# Minibatch accuracy: 81.2%
# Validation accuracy: 72.2%
# Minibatch loss at step 7700: 5.601329
# Minibatch accuracy: 62.5%
# Validation accuracy: 73.5%
# Minibatch loss at step 7750: 7.399806
# Minibatch accuracy: 62.5%
# Validation accuracy: 73.8%
# Minibatch loss at step 7800: 3.286792
# Minibatch accuracy: 56.2%
# Validation accuracy: 76.3%
# Minibatch loss at step 7850: 4.236605
# Minibatch accuracy: 81.2%
# Validation accuracy: 73.2%
# Minibatch loss at step 7900: 3.198841
# Minibatch accuracy: 81.2%
# Validation accuracy: 76.3%
# Minibatch loss at step 7950: 5.690884
# Minibatch accuracy: 62.5%
# Validation accuracy: 72.8%
# Minibatch loss at step 8000: 10.115949
# Minibatch accuracy: 56.2%
# Validation accuracy: 75.2%
# Minibatch loss at step 8050: 1.266350
# Minibatch accuracy: 81.2%
# Validation accuracy: 75.0%
# Minibatch loss at step 8100: 4.264094
# Minibatch accuracy: 62.5%
# Validation accuracy: 75.3%
# Minibatch loss at step 8150: 2.736811
# Minibatch accuracy: 87.5%
# Validation accuracy: 76.3%
# Minibatch loss at step 8200: 2.931811
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.3%
# Minibatch loss at step 8250: 7.283390
# Minibatch accuracy: 68.8%
# Validation accuracy: 76.2%
# Minibatch loss at step 8300: 3.109098
# Minibatch accuracy: 81.2%
# Validation accuracy: 74.8%
# Minibatch loss at step 8350: 2.369341
# Minibatch accuracy: 81.2%
# Validation accuracy: 76.0%
# Minibatch loss at step 8400: 5.672517
# Minibatch accuracy: 68.8%
# Validation accuracy: 75.0%
# Minibatch loss at step 8450: 3.704918
# Minibatch accuracy: 62.5%
# Validation accuracy: 75.7%
# Minibatch loss at step 8500: 3.038719
# Minibatch accuracy: 87.5%
# Validation accuracy: 74.7%
# Minibatch loss at step 8550: 7.607154
# Minibatch accuracy: 56.2%
# Validation accuracy: 76.0%
# Minibatch loss at step 8600: 5.689425
# Minibatch accuracy: 62.5%
# Validation accuracy: 73.2%
# Minibatch loss at step 8650: 3.892999
# Minibatch accuracy: 75.0%
# Validation accuracy: 75.3%
# Minibatch loss at step 8700: 4.793586
# Minibatch accuracy: 75.0%
# Validation accuracy: 74.5%
# Minibatch loss at step 8750: 6.738487
# Minibatch accuracy: 68.8%
# Validation accuracy: 74.5%
# Minibatch loss at step 8800: 2.210853
# Minibatch accuracy: 75.0%
# Validation accuracy: 76.3%
# Minibatch loss at step 8850: 8.949408
# Minibatch accuracy: 68.8%
# Validation accuracy: 74.3%
# Minibatch loss at step 8900: 7.882156
# Minibatch accuracy: 62.5%
# Validation accuracy: 75.2%
# Minibatch loss at step 8950: 3.568464
# Minibatch accuracy: 81.2%
# Validation accuracy: 74.5%
# Minibatch loss at step 9000: 7.124979
# Minibatch accuracy: 68.8%
# Validation accuracy: 75.8%
# Minibatch loss at step 9050: 6.618361
# Minibatch accuracy: 62.5%
# Validation accuracy: 76.3%
# Minibatch loss at step 9100: 4.443408
# Minibatch accuracy: 56.2%
# Validation accuracy: 77.0%
# Minibatch loss at step 9150: 5.202218
# Minibatch accuracy: 68.8%
# Validation accuracy: 77.3%
# Minibatch loss at step 9200: 4.039663
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.5%
# Minibatch loss at step 9250: 3.285401
# Minibatch accuracy: 75.0%
# Validation accuracy: 75.3%
# Minibatch loss at step 9300: 4.767027
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.3%
# Minibatch loss at step 9350: 2.676543
# Minibatch accuracy: 68.8%
# Validation accuracy: 76.8%
# Minibatch loss at step 9400: 4.329954
# Minibatch accuracy: 75.0%
# Validation accuracy: 74.7%
# Minibatch loss at step 9450: 6.424349
# Minibatch accuracy: 56.2%
# Validation accuracy: 75.5%
# Minibatch loss at step 9500: 5.506788
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.0%
# Minibatch loss at step 9550: 0.678545
# Minibatch accuracy: 93.8%
# Validation accuracy: 75.8%
# Minibatch loss at step 9600: 4.601225
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.2%
# Minibatch loss at step 9650: 4.462584
# Minibatch accuracy: 50.0%
# Validation accuracy: 75.7%
# Minibatch loss at step 9700: 9.207663
# Minibatch accuracy: 56.2%
# Validation accuracy: 76.3%
# Minibatch loss at step 9750: 2.380612
# Minibatch accuracy: 68.8%
# Validation accuracy: 78.3%
# Minibatch loss at step 9800: 2.485845
# Minibatch accuracy: 75.0%
# Validation accuracy: 76.7%
# Minibatch loss at step 9850: 5.530293
# Minibatch accuracy: 62.5%
# Validation accuracy: 76.5%
# Minibatch loss at step 9900: 0.272139
# Minibatch accuracy: 93.8%
# Validation accuracy: 77.8%
# Minibatch loss at step 9950: 3.454693
# Minibatch accuracy: 68.8%
# Validation accuracy: 77.3%
# Minibatch loss at step 10000: 3.824514
# Minibatch accuracy: 87.5%
# Validation accuracy: 75.3%
# Minibatch loss at step 10050: 2.766573
# Minibatch accuracy: 87.5%
# Validation accuracy: 76.8%
# Minibatch loss at step 10100: 3.908938
# Minibatch accuracy: 81.2%
# Validation accuracy: 76.0%
# Minibatch loss at step 10150: 4.489828
# Minibatch accuracy: 68.8%
# Validation accuracy: 76.7%
# Minibatch loss at step 10200: 2.552306
# Minibatch accuracy: 68.8%
# Validation accuracy: 75.8%
# Minibatch loss at step 10250: 6.970996
# Minibatch accuracy: 68.8%
# Validation accuracy: 77.2%
# Minibatch loss at step 10300: 1.777543
# Minibatch accuracy: 81.2%
# Validation accuracy: 76.3%
# Minibatch loss at step 10350: 4.299993
# Minibatch accuracy: 75.0%
# Validation accuracy: 75.0%
# Minibatch loss at step 10400: 5.795256
# Minibatch accuracy: 75.0%
# Validation accuracy: 76.0%
# Minibatch loss at step 10450: 5.776418
# Minibatch accuracy: 68.8%
# Validation accuracy: 72.7%
# Minibatch loss at step 10500: 6.525316
# Minibatch accuracy: 62.5%
# Validation accuracy: 74.8%
# Minibatch loss at step 10550: 1.841098
# Minibatch accuracy: 93.8%
# Validation accuracy: 75.0%
# Minibatch loss at step 10600: 1.824327
# Minibatch accuracy: 87.5%
# Validation accuracy: 76.5%
# Minibatch loss at step 10650: 2.831534
# Minibatch accuracy: 81.2%
# Validation accuracy: 73.7%
# Minibatch loss at step 10700: 3.113562
# Minibatch accuracy: 75.0%
# Validation accuracy: 75.2%
# Minibatch loss at step 10750: 2.448788
# Minibatch accuracy: 81.2%
# Validation accuracy: 76.2%
# Minibatch loss at step 10800: 4.983447
# Minibatch accuracy: 56.2%
# Validation accuracy: 74.7%
# Minibatch loss at step 10850: 6.475065
# Minibatch accuracy: 68.8%
# Validation accuracy: 76.5%
# Minibatch loss at step 10900: 4.582365
# Minibatch accuracy: 87.5%
# Validation accuracy: 76.8%
# Minibatch loss at step 10950: 7.060097
# Minibatch accuracy: 68.8%
# Validation accuracy: 76.5%
# Minibatch loss at step 11000: 0.794131
# Minibatch accuracy: 87.5%
# Validation accuracy: 76.7%
# Minibatch loss at step 11050: 3.889029
# Minibatch accuracy: 75.0%
# Validation accuracy: 74.3%
# Minibatch loss at step 11100: 2.777713
# Minibatch accuracy: 87.5%
# Validation accuracy: 75.5%
# Minibatch loss at step 11150: 0.726222
# Minibatch accuracy: 81.2%
# Validation accuracy: 76.0%
# Minibatch loss at step 11200: 3.747996
# Minibatch accuracy: 68.8%
# Validation accuracy: 76.3%
# Minibatch loss at step 11250: 2.865914
# Minibatch accuracy: 81.2%
# Validation accuracy: 75.5%
# Minibatch loss at step 11300: 4.256836
# Minibatch accuracy: 68.8%
# Validation accuracy: 76.7%
# Minibatch loss at step 11350: 6.314636
# Minibatch accuracy: 62.5%
# Validation accuracy: 77.3%
# Minibatch loss at step 11400: 4.663256
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.3%
# Minibatch loss at step 11450: 5.231726
# Minibatch accuracy: 81.2%
# Validation accuracy: 76.5%
# Minibatch loss at step 11500: 3.653293
# Minibatch accuracy: 62.5%
# Validation accuracy: 77.3%
# Minibatch loss at step 11550: 1.123310
# Minibatch accuracy: 68.8%
# Validation accuracy: 76.3%
# Minibatch loss at step 11600: 1.547391
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.0%
# Minibatch loss at step 11650: 5.772151
# Minibatch accuracy: 62.5%
# Validation accuracy: 76.7%
# Minibatch loss at step 11700: 1.486421
# Minibatch accuracy: 75.0%
# Validation accuracy: 75.8%
# Minibatch loss at step 11750: 2.939219
# Minibatch accuracy: 75.0%
# Validation accuracy: 76.7%
# Minibatch loss at step 11800: 3.871015
# Minibatch accuracy: 68.8%
# Validation accuracy: 75.7%
# Minibatch loss at step 11850: 3.988791
# Minibatch accuracy: 75.0%
# Validation accuracy: 76.5%
# Minibatch loss at step 11900: 4.216527
# Minibatch accuracy: 75.0%
# Validation accuracy: 75.5%
# Minibatch loss at step 11950: 1.350109
# Minibatch accuracy: 87.5%
# Validation accuracy: 75.8%
# Minibatch loss at step 12000: 5.103195
# Minibatch accuracy: 62.5%
# Validation accuracy: 77.0%
# Minibatch loss at step 12050: 1.836871
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.0%
# Minibatch loss at step 12100: 5.038339
# Minibatch accuracy: 62.5%
# Validation accuracy: 77.0%
# Minibatch loss at step 12150: 4.244669
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.3%
# Minibatch loss at step 12200: 4.868154
# Minibatch accuracy: 68.8%
# Validation accuracy: 76.7%
# Minibatch loss at step 12250: 2.533946
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.8%
# Minibatch loss at step 12300: 4.125635
# Minibatch accuracy: 68.8%
# Validation accuracy: 76.3%
# Minibatch loss at step 12350: 6.410128
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.7%
# Minibatch loss at step 12400: 1.768566
# Minibatch accuracy: 93.8%
# Validation accuracy: 77.7%
# Minibatch loss at step 12450: 0.873602
# Minibatch accuracy: 93.8%
# Validation accuracy: 77.8%
# Minibatch loss at step 12500: 2.790292
# Minibatch accuracy: 56.2%
# Validation accuracy: 78.7%
# Minibatch loss at step 12550: 0.025564
# Minibatch accuracy: 100.0%
# Validation accuracy: 77.8%
# Minibatch loss at step 12600: 2.810380
# Minibatch accuracy: 75.0%
# Validation accuracy: 76.5%
# Minibatch loss at step 12650: 2.608717
# Minibatch accuracy: 68.8%
# Validation accuracy: 77.2%
# Minibatch loss at step 12700: 4.267623
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.2%
# Minibatch loss at step 12750: 1.831058
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.3%
# Minibatch loss at step 12800: 2.595033
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.5%
# Minibatch loss at step 12850: 3.773229
# Minibatch accuracy: 68.8%
# Validation accuracy: 78.3%
# Minibatch loss at step 12900: 5.764737
# Minibatch accuracy: 56.2%
# Validation accuracy: 77.0%
# Minibatch loss at step 12950: 3.512590
# Minibatch accuracy: 75.0%
# Validation accuracy: 75.7%
# Minibatch loss at step 13000: 5.847067
# Minibatch accuracy: 68.8%
# Validation accuracy: 76.8%
# Minibatch loss at step 13050: 5.848799
# Minibatch accuracy: 68.8%
# Validation accuracy: 75.8%
# Minibatch loss at step 13100: 1.347786
# Minibatch accuracy: 87.5%
# Validation accuracy: 76.0%
# Minibatch loss at step 13150: 2.456813
# Minibatch accuracy: 62.5%
# Validation accuracy: 75.8%
# Minibatch loss at step 13200: 3.602655
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.3%
# Minibatch loss at step 13250: 2.674098
# Minibatch accuracy: 62.5%
# Validation accuracy: 77.5%
# Minibatch loss at step 13300: 7.330481
# Minibatch accuracy: 62.5%
# Validation accuracy: 77.7%
# Minibatch loss at step 13350: 6.499419
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.2%
# Minibatch loss at step 13400: 5.311628
# Minibatch accuracy: 62.5%
# Validation accuracy: 77.7%
# Minibatch loss at step 13450: 1.274181
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.5%
# Minibatch loss at step 13500: 0.672919
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.2%
# Minibatch loss at step 13550: 3.606533
# Minibatch accuracy: 68.8%
# Validation accuracy: 77.0%
# Minibatch loss at step 13600: 1.793272
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.5%
# Minibatch loss at step 13650: 4.967317
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.0%
# Minibatch loss at step 13700: 5.838878
# Minibatch accuracy: 62.5%
# Validation accuracy: 78.8%
# Minibatch loss at step 13750: 2.351215
# Minibatch accuracy: 62.5%
# Validation accuracy: 78.7%
# Minibatch loss at step 13800: 3.598683
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.3%
# Minibatch loss at step 13850: 1.460785
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.7%
# Minibatch loss at step 13900: 4.848599
# Minibatch accuracy: 62.5%
# Validation accuracy: 77.3%
# Minibatch loss at step 13950: 0.670282
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.8%
# Minibatch loss at step 14000: 4.498260
# Minibatch accuracy: 62.5%
# Validation accuracy: 76.3%
# Minibatch loss at step 14050: 3.192042
# Minibatch accuracy: 81.2%
# Validation accuracy: 76.5%
# Minibatch loss at step 14100: 3.307360
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.0%
# Minibatch loss at step 14150: 4.370821
# Minibatch accuracy: 75.0%
# Validation accuracy: 76.2%
# Minibatch loss at step 14200: 6.473852
# Minibatch accuracy: 68.8%
# Validation accuracy: 77.2%
# Minibatch loss at step 14250: 4.157168
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.0%
# Minibatch loss at step 14300: 1.057998
# Minibatch accuracy: 87.5%
# Validation accuracy: 76.3%
# Minibatch loss at step 14350: 6.854699
# Minibatch accuracy: 62.5%
# Validation accuracy: 76.2%
# Minibatch loss at step 14400: 2.528665
# Minibatch accuracy: 62.5%
# Validation accuracy: 76.3%
# Minibatch loss at step 14450: 5.872779
# Minibatch accuracy: 68.8%
# Validation accuracy: 77.2%
# Minibatch loss at step 14500: 3.206518
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.2%
# Minibatch loss at step 14550: 2.965228
# Minibatch accuracy: 68.8%
# Validation accuracy: 77.2%
# Minibatch loss at step 14600: 8.170651
# Minibatch accuracy: 43.8%
# Validation accuracy: 75.8%
# Minibatch loss at step 14650: 0.851811
# Minibatch accuracy: 93.8%
# Validation accuracy: 76.7%
# Minibatch loss at step 14700: 3.368257
# Minibatch accuracy: 56.2%
# Validation accuracy: 77.7%
# Minibatch loss at step 14750: 1.395002
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.5%
# Minibatch loss at step 14800: 1.432932
# Minibatch accuracy: 81.2%
# Validation accuracy: 76.5%
# Minibatch loss at step 14850: 1.737565
# Minibatch accuracy: 87.5%
# Validation accuracy: 76.5%
# Minibatch loss at step 14900: 3.471545
# Minibatch accuracy: 68.8%
# Validation accuracy: 77.7%
# Minibatch loss at step 14950: 7.649447
# Minibatch accuracy: 56.2%
# Validation accuracy: 77.3%
# Minibatch loss at step 15000: 2.511633
# Minibatch accuracy: 87.5%
# Validation accuracy: 76.7%
# Minibatch loss at step 15050: 3.051332
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.3%
# Minibatch loss at step 15100: 3.355768
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.2%
# Minibatch loss at step 15150: 0.846199
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.3%
# Minibatch loss at step 15200: 7.333277
# Minibatch accuracy: 62.5%
# Validation accuracy: 77.7%
# Minibatch loss at step 15250: 4.254384
# Minibatch accuracy: 68.8%
# Validation accuracy: 78.2%
# Minibatch loss at step 15300: 3.538527
# Minibatch accuracy: 75.0%
# Validation accuracy: 76.8%
# Minibatch loss at step 15350: 5.577797
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.2%
# Minibatch loss at step 15400: 6.722541
# Minibatch accuracy: 56.2%
# Validation accuracy: 78.3%
# Minibatch loss at step 15450: 1.915615
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.5%
# Minibatch loss at step 15500: 0.723797
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.0%
# Minibatch loss at step 15550: 2.277510
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.2%
# Minibatch loss at step 15600: 4.183287
# Minibatch accuracy: 68.8%
# Validation accuracy: 78.3%
# Minibatch loss at step 15650: 2.154455
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.2%
# Minibatch loss at step 15700: 0.536388
# Minibatch accuracy: 93.8%
# Validation accuracy: 77.8%
# Minibatch loss at step 15750: 2.201473
# Minibatch accuracy: 81.2%
# Validation accuracy: 76.5%
# Minibatch loss at step 15800: 2.034115
# Minibatch accuracy: 68.8%
# Validation accuracy: 77.7%
# Minibatch loss at step 15850: 3.705884
# Minibatch accuracy: 75.0%
# Validation accuracy: 76.5%
# Minibatch loss at step 15900: 3.929824
# Minibatch accuracy: 75.0%
# Validation accuracy: 76.3%
# Minibatch loss at step 15950: 0.378571
# Minibatch accuracy: 93.8%
# Validation accuracy: 77.3%
# Minibatch loss at step 16000: 1.986935
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.0%
# Minibatch loss at step 16050: 3.454522
# Minibatch accuracy: 68.8%
# Validation accuracy: 77.2%
# Minibatch loss at step 16100: 0.294541
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.5%
# Minibatch loss at step 16150: 4.433696
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.2%
# Minibatch loss at step 16200: 3.459960
# Minibatch accuracy: 68.8%
# Validation accuracy: 76.0%
# Minibatch loss at step 16250: 0.679824
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.0%
# Minibatch loss at step 16300: 4.767142
# Minibatch accuracy: 68.8%
# Validation accuracy: 77.2%
# Minibatch loss at step 16350: 5.533529
# Minibatch accuracy: 68.8%
# Validation accuracy: 76.8%
# Minibatch loss at step 16400: 1.684507
# Minibatch accuracy: 93.8%
# Validation accuracy: 77.7%
# Minibatch loss at step 16450: 4.317194
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.7%
# Minibatch loss at step 16500: 1.922703
# Minibatch accuracy: 81.2%
# Validation accuracy: 76.8%
# Minibatch loss at step 16550: 3.597713
# Minibatch accuracy: 68.8%
# Validation accuracy: 77.2%
# Minibatch loss at step 16600: 2.924732
# Minibatch accuracy: 68.8%
# Validation accuracy: 77.8%
# Minibatch loss at step 16650: 1.618473
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.2%
# Minibatch loss at step 16700: 1.913003
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.0%
# Minibatch loss at step 16750: 0.429357
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.0%
# Minibatch loss at step 16800: 2.336983
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.3%
# Minibatch loss at step 16850: 5.381163
# Minibatch accuracy: 68.8%
# Validation accuracy: 76.3%
# Minibatch loss at step 16900: 2.292799
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.0%
# Minibatch loss at step 16950: 6.554011
# Minibatch accuracy: 56.2%
# Validation accuracy: 78.0%
# Minibatch loss at step 17000: 0.326640
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.0%
# Minibatch loss at step 17050: 1.886732
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.5%
# Minibatch loss at step 17100: 5.495737
# Minibatch accuracy: 56.2%
# Validation accuracy: 77.8%
# Minibatch loss at step 17150: 4.192522
# Minibatch accuracy: 62.5%
# Validation accuracy: 78.3%
# Minibatch loss at step 17200: 4.790645
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.8%
# Minibatch loss at step 17250: 2.413144
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.8%
# Minibatch loss at step 17300: 4.624707
# Minibatch accuracy: 68.8%
# Validation accuracy: 78.0%
# Minibatch loss at step 17350: 4.390916
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.2%
# Minibatch loss at step 17400: 4.903119
# Minibatch accuracy: 68.8%
# Validation accuracy: 77.5%
# Minibatch loss at step 17450: 2.304716
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.3%
# Minibatch loss at step 17500: 4.796018
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.8%
# Minibatch loss at step 17550: 4.347135
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.7%
# Minibatch loss at step 17600: 4.125661
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.5%
# Minibatch loss at step 17650: 1.667420
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.0%
# Minibatch loss at step 17700: 1.532047
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.5%
# Minibatch loss at step 17750: 0.545395
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.0%
# Minibatch loss at step 17800: 1.787931
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.7%
# Minibatch loss at step 17850: 1.712094
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.3%
# Minibatch loss at step 17900: 7.365882
# Minibatch accuracy: 62.5%
# Validation accuracy: 76.7%
# Minibatch loss at step 17950: 2.998292
# Minibatch accuracy: 68.8%
# Validation accuracy: 77.8%
# Minibatch loss at step 18000: 6.242393
# Minibatch accuracy: 56.2%
# Validation accuracy: 77.7%
# Minibatch loss at step 18050: 3.548672
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.7%
# Minibatch loss at step 18100: 1.640435
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.3%
# Minibatch loss at step 18150: 0.959738
# Minibatch accuracy: 93.8%
# Validation accuracy: 77.0%
# Minibatch loss at step 18200: 4.320811
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.3%
# Minibatch loss at step 18250: 3.193503
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.8%
# Minibatch loss at step 18300: 2.567138
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.3%
# Minibatch loss at step 18350: 2.038042
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.5%
# Minibatch loss at step 18400: 2.784430
# Minibatch accuracy: 62.5%
# Validation accuracy: 79.0%
# Minibatch loss at step 18450: 0.126853
# Minibatch accuracy: 93.8%
# Validation accuracy: 76.3%
# Minibatch loss at step 18500: 4.521715
# Minibatch accuracy: 62.5%
# Validation accuracy: 77.8%
# Minibatch loss at step 18550: 0.206514
# Minibatch accuracy: 93.8%
# Validation accuracy: 77.7%
# Minibatch loss at step 18600: 4.721022
# Minibatch accuracy: 68.8%
# Validation accuracy: 76.3%
# Minibatch loss at step 18650: 2.010816
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.3%
# Minibatch loss at step 18700: 0.813180
# Minibatch accuracy: 93.8%
# Validation accuracy: 77.5%
# Minibatch loss at step 18750: 2.364477
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.5%
# Minibatch loss at step 18800: 2.071176
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.8%
# Minibatch loss at step 18850: 0.799424
# Minibatch accuracy: 93.8%
# Validation accuracy: 77.8%
# Minibatch loss at step 18900: 4.510689
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.3%
# Minibatch loss at step 18950: 5.736820
# Minibatch accuracy: 62.5%
# Validation accuracy: 77.7%
# Minibatch loss at step 19000: 2.913226
# Minibatch accuracy: 56.2%
# Validation accuracy: 78.0%
# Minibatch loss at step 19050: 5.027549
# Minibatch accuracy: 68.8%
# Validation accuracy: 77.3%
# Minibatch loss at step 19100: 2.002606
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.5%
# Minibatch loss at step 19150: 5.893366
# Minibatch accuracy: 68.8%
# Validation accuracy: 78.0%
# Minibatch loss at step 19200: 2.429924
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.5%
# Minibatch loss at step 19250: 5.274840
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.2%
# Minibatch loss at step 19300: 0.929057
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.8%
# Minibatch loss at step 19350: 0.268589
# Minibatch accuracy: 93.8%
# Validation accuracy: 77.5%
# Minibatch loss at step 19400: 2.700522
# Minibatch accuracy: 68.8%
# Validation accuracy: 77.7%
# Minibatch loss at step 19450: 1.566364
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.7%
# Minibatch loss at step 19500: 2.599984
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.7%
# Minibatch loss at step 19550: 5.494177
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.0%
# Minibatch loss at step 19600: 1.821130
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.2%
# Minibatch loss at step 19650: 3.231305
# Minibatch accuracy: 68.8%
# Validation accuracy: 77.2%
# Minibatch loss at step 19700: 3.070766
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.2%
# Minibatch loss at step 19750: 0.026491
# Minibatch accuracy: 100.0%
# Validation accuracy: 76.8%
# Minibatch loss at step 19800: 5.209050
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.3%
# Minibatch loss at step 19850: 4.540079
# Minibatch accuracy: 87.5%
# Validation accuracy: 76.7%
# Minibatch loss at step 19900: 3.481225
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.3%
# Minibatch loss at step 19950: 1.313028
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.5%
# Minibatch loss at step 20000: 1.857717
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.2%
# Test accuracy: 75.3%

# %% [markdown]
# The result is worst. This net has so many meta parameters to tuning: initial learning rate, learning rate decay, decay step, decay rate, batch size, weight initialization, ... Basically I just set it by guessing. Maybe I should find a way to fine tuning all this parameters.
#
# I will do so in a next version.
